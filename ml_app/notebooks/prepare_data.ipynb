# %%
import os
import zipfile
import shutil
from pathlib import Path
from tqdm import tqdm

# Set up paths
project_root = Path(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
zip_file_1 = Path(r"C:\Users\mohan\Downloads\OneDrive_2024-09-16.zip")
zip_file_2 = Path(r"C:\Users\mohan\Downloads\OneDrive_2024-10-03.zip")
output_folder = project_root / 'ml_app' / 'images_data'

# Create the output folder if it doesn't exist
output_folder.mkdir(parents=True, exist_ok=True)

print(f"Output folder: {output_folder}")
# Out:
# Output folder: c:\Users\mohan\Desktop\blister\ml_app\images_data

# %%
def extract_images_from_zip(zip_path, output_folder):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        for file in tqdm(zip_ref.namelist(), desc=f"Extracting from {zip_path.name}"):
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
                # Extract the file to a temporary location
                zip_ref.extract(file, path=output_folder)
                
                # Move the file to the root of the output folder
                temp_path = output_folder / file
                new_path = output_folder / temp_path.name
                shutil.move(str(temp_path), str(new_path))
                
                # Remove any empty directories created during extraction
                temp_dir = temp_path.parent
                while temp_dir != output_folder:
                    try:
                        temp_dir.rmdir()
                        temp_dir = temp_dir.parent
                    except OSError:
                        # Directory not empty or already removed
                        break

# %%
# Extract images from the first zip file
extract_images_from_zip(zip_file_1, output_folder)

# Extract images from the second zip file
extract_images_from_zip(zip_file_2, output_folder)

# Count the number of extracted images
image_count = len(list(output_folder.glob('*')))
print(f"Total images extracted: {image_count}")

# %% [markdown]
# # Resize the images to yolo standard

# %%
import os
from pathlib import Path
from PIL import Image
from tqdm import tqdm

# Set up paths
project_root = Path(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
input_folder = project_root / 'ml_app' / 'images_data'
output_folder = project_root / 'ml_app' / 'resized_images'

# Create output folder if it doesn't exist
output_folder.mkdir(parents=True, exist_ok=True)

# Set the target size (YOLO typically uses multiples of 32)
target_size = (640, 640)  # You can adjust this size based on your needs

def resize_image(input_path, output_path, target_size):
    with Image.open(input_path) as img:
        # Resize the image
        img = img.resize(target_size, Image.LANCZOS)
        
        # Save the resized image
        img.save(output_path, quality=95)  # Adjust quality as needed

# Resize all images
for img_path in tqdm(list(input_folder.glob('*')), desc="Resizing images"):
    if img_path.suffix.lower() in ['.jpg', '.jpeg', '.png', '.bmp']:
        output_path = output_folder / img_path.name
        resize_image(img_path, output_path, target_size)

print(f"Resized images saved to: {output_folder}")
print(f"Total images resized: {len(list(output_folder.glob('*')))}")

# %% [markdown]
# # prepare synthetic data

# %%
import os
import shutil
from PIL import Image, ImageDraw, ImageFilter
import random
import numpy as np
import time

def add_texture(img, intensity=20):
    arr = np.array(img)
    noise = np.random.randint(-intensity, intensity, arr.shape, dtype=np.int16)
    arr = np.clip(arr + noise, 0, 255).astype(np.uint8)
    return Image.fromarray(arr)

def create_irregular_mask(size):
    mask = Image.new('L', (size*2, size*2), 0)
    draw = ImageDraw.Draw(mask)
    
    # Create a more irregular shape
    points = []
    for i in range(12):  # Increased number of points for more irregularity
        angle = i * (2 * np.pi / 12) + random.uniform(-0.2, 0.2)
        r = size * random.uniform(0.8, 1.2)
        points.append((
            size + r * np.cos(angle),
            size + r * np.sin(angle)
        ))
    
    draw.polygon(points, fill=255)
    mask = mask.filter(ImageFilter.GaussianBlur(radius=size/10))
    return np.array(mask) / 255.0

def create_synthetic_image(size=(480, 640)):
    bg_color = (random.randint(150, 250), random.randint(100, 250), random.randint(100, 250))
    img = Image.new('RGB', size, color=bg_color)
    img = add_texture(img, intensity=10)
    draw = ImageDraw.Draw(img)

    # Add X marking
    x_color = (max(0, bg_color[0] - 50), max(0, bg_color[1] - 50), max(0, bg_color[2] - 50))
    x_size = int(size[0] * 0.4)
    center_x = size[0] // 2
    center_y = int(size[1] * 0.4)
    line_width = random.randint(2, 4)  # Keeping the original thickness
    draw.line((center_x - x_size//2, center_y - x_size//2, center_x + x_size//2, center_y + x_size//2), fill=x_color, width=line_width)
    draw.line((center_x - x_size//2, center_y + x_size//2, center_x + x_size//2, center_y - x_size//2), fill=x_color, width=line_width)

    # Add horizontal line towards the bottom
    line_y = int(size[1] * 0.85)
    draw.line((center_x - x_size//2, line_y, center_x + x_size//2, line_y), fill=x_color, width=line_width)

    img_array = np.array(img)

    # Add blisters and create annotations
    num_blisters = random.randint(20, 60)  # Doubled the number of individual blisters
    blisters = []
    
    # Create clustered blisters
    num_clusters = random.randint(1, 3)
    for _ in range(num_clusters):
        cluster_center_x = random.randint(0, size[0])
        cluster_center_y = random.randint(0, size[1])
        num_cluster_blisters = random.randint(3, 8)
        
        for _ in range(num_cluster_blisters):
            blister_x = min(max(0, cluster_center_x + random.randint(-30, 30)), size[0]-1)
            blister_y = min(max(0, cluster_center_y + random.randint(-30, 30)), size[1]-1)
            blister_size = random.randint(2, 15)  # Increased max size
            
            create_blister(img_array, blister_x, blister_y, blister_size, bg_color, size)
            blisters.append(create_annotation(blister_x, blister_y, blister_size, size))

    # Create individual blisters
    for _ in range(num_blisters - num_clusters * num_cluster_blisters):
        blister_x = random.randint(0, size[0]-1)
        blister_y = random.randint(0, size[1]-1)
        blister_size = random.randint(2, 25)  # Increased size range
        
        create_blister(img_array, blister_x, blister_y, blister_size, bg_color, size)
        blisters.append(create_annotation(blister_x, blister_y, blister_size, size))

    img = Image.fromarray(img_array)
    return img, blisters

def create_blister(img_array, blister_x, blister_y, blister_size, bg_color, size):
    mask = create_irregular_mask(blister_size)
    
    # Determine blister color (mostly background color, some whitish)
    if random.random() < 0.2:  # 20% chance of whitish blister
        blister_color = np.array([random.randint(220, 255), random.randint(220, 255), random.randint(220, 255)])
    else:
        blister_color = np.array([
            max(0, min(255, bg_color[0] + random.randint(-20, 20))),
            max(0, min(255, bg_color[1] + random.randint(-20, 20))),
            max(0, min(255, bg_color[2] + random.randint(-20, 20)))
        ])

    # Apply blister to image
    for i in range(blister_size*2):
        for j in range(blister_size*2):
            if blister_x+i < size[0] and blister_y+j < size[1]:
                img_array[blister_y+j, blister_x+i] = (
                    img_array[blister_y+j, blister_x+i] * (1 - mask[j, i]) +
                    blister_color * mask[j, i]
                ).astype(np.uint8)

    # Add subtle highlight
    highlight_color = np.array([min(255, c + 30) for c in blister_color])
    highlight_size = max(1, blister_size // 4)
    highlight_mask = create_irregular_mask(highlight_size)
    
    highlight_x = blister_x + blister_size - highlight_size
    highlight_y = blister_y + blister_size - highlight_size

    for i in range(highlight_size*2):
        for j in range(highlight_size*2):
            if highlight_x+i < size[0] and highlight_y+j < size[1]:
                img_array[highlight_y+j, highlight_x+i] = (
                    img_array[highlight_y+j, highlight_x+i] * (1 - highlight_mask[j, i]) +
                    highlight_color * highlight_mask[j, i]
                ).astype(np.uint8)

def create_annotation(blister_x, blister_y, blister_size, size):
    x_center = (blister_x + blister_size) / size[0]
    y_center = (blister_y + blister_size) / size[1]
    width = (2 * blister_size) / size[0]
    height = (2 * blister_size) / size[1]
    return f"0 {x_center} {y_center} {width} {height}"

def clear_directory(directory):
    if os.path.exists(directory):
        shutil.rmtree(directory)
    os.makedirs(directory)

def generate_dataset(num_images, output_dir):
    print(f"Starting to generate {num_images} synthetic images...")
    start_time = time.time()

    # Clear existing data
    clear_directory(output_dir)

    # Create directory structure
    for data_type in ['images', 'labels']:
        for subset in ['train', 'test', 'val']:
            os.makedirs(os.path.join(output_dir, data_type, subset), exist_ok=True)

    for i in range(num_images):
        if i % 10 == 0:
            print(f"Generating image {i+1}/{num_images}...")
        
        try:
            img, blisters = create_synthetic_image()
            
            # Determine which subset this image belongs to
            if i < num_images * 0.7:
                subset = 'train'
            elif i < num_images * 0.9:
                subset = 'test'
            else:
                subset = 'val'
            
            # Save image
            img_path = os.path.join(output_dir, 'images', subset, f'synthetic_{i:04d}.png')
            img.save(img_path)
            
            # Save annotations
            label_path = os.path.join(output_dir, 'labels', subset, f'synthetic_{i:04d}.txt')
            with open(label_path, 'w') as f:
                f.write('\n'.join(blisters))
        except Exception as e:
            print(f"Error generating image {i+1}: {str(e)}")

    end_time = time.time()
    print(f"Generated {num_images} synthetic images and annotations in {output_dir}")
    print(f"Distribution: {num_images * 0.7:.0f} train, {num_images * 0.2:.0f} test, {num_images * 0.1:.0f} val")
    print(f"Total time taken: {end_time - start_time:.2f} seconds")

# %%
if __name__ == "__main__":
    print("Synthetic Data Generator Script Starting...")
    output_dir = r"C:\Users\mohan\Desktop\blister\ml_app\datasets\synthetic_dataset"
    num_images = 5000
    generate_dataset(num_images, output_dir)
    print("Script execution completed.")
# Out:
# Synthetic Data Generator Script Starting...
# Starting to generate 5000 synthetic images...
# Generating image 1/5000...
# Generating image 11/5000...
# Generating image 21/5000...
# Generating image 31/5000...
# Generating image 41/5000...
# Generating image 51/5000...
# Generating image 61/5000...
# Generating image 71/5000...
# Generating image 81/5000...
# Generating image 91/5000...
# Generating image 101/5000...
# Generating image 111/5000...
# Generating image 121/5000...
# Generating image 131/5000...
# Generating image 141/5000...
# Generating image 151/5000...
# Generating image 161/5000...
# Generating image 171/5000...
# Generating image 181/5000...
# Generating image 191/5000...
# Generating image 201/5000...
# Generating image 211/5000...
# Generating image 221/5000...
# Generating image 231/5000...
# Generating image 241/5000...
# Generating image 251/5000...
# Generating image 261/5000...
# Generating image 271/5000...
# Generating image 281/5000...
# Generating image 291/5000...
# Generating image 301/5000...
# Generating image 311/5000...
# Generating image 321/5000...
# Generating image 331/5000...
# Generating image 341/5000...
# Generating image 351/5000...
# Generating image 361/5000...
# Generating image 371/5000...
# Generating image 381/5000...
# Generating image 391/5000...
# Generating image 401/5000...
# Generating image 411/5000...
# Generating image 421/5000...
# Generating image 431/5000...
# Generating image 441/5000...
# Generating image 451/5000...
# Generating image 461/5000...
# Generating image 471/5000...
# Generating image 481/5000...
# Generating image 491/5000...
# Generating image 501/5000...
# Generating image 511/5000...
# Generating image 521/5000...
# Generating image 531/5000...
# Generating image 541/5000...
# Generating image 551/5000...
# Generating image 561/5000...
# Generating image 571/5000...
# Generating image 581/5000...
# Generating image 591/5000...
# Generating image 601/5000...
# Generating image 611/5000...
# Generating image 621/5000...
# Generating image 631/5000...
# Generating image 641/5000...
# Generating image 651/5000...
# Generating image 661/5000...
# Generating image 671/5000...
# Generating image 681/5000...
# Generating image 691/5000...
# Generating image 701/5000...
# Generating image 711/5000...
# Generating image 721/5000...
# Generating image 731/5000...
# Generating image 741/5000...
# Generating image 751/5000...
# Generating image 761/5000...
# Generating image 771/5000...
# Generating image 781/5000...
# Generating image 791/5000...
# Generating image 801/5000...
# Generating image 811/5000...
# Generating image 821/5000...
# Generating image 831/5000...
# Generating image 841/5000...
# Generating image 851/5000...
# Generating image 861/5000...
# Generating image 871/5000...
# Generating image 881/5000...
# Generating image 891/5000...
# Generating image 901/5000...
# Generating image 911/5000...
# Generating image 921/5000...
# Generating image 931/5000...
# Generating image 941/5000...
# Generating image 951/5000...
# Generating image 961/5000...
# Generating image 971/5000...
# Generating image 981/5000...
# Generating image 991/5000...
# Generating image 1001/5000...
# Generating image 1011/5000...
# Generating image 1021/5000...
# Generating image 1031/5000...
# Generating image 1041/5000...
# Generating image 1051/5000...
# Generating image 1061/5000...
# Generating image 1071/5000...
# Generating image 1081/5000...
# Generating image 1091/5000...
# Generating image 1101/5000...
# Generating image 1111/5000...
# Generating image 1121/5000...
# Generating image 1131/5000...
# Generating image 1141/5000...
# Generating image 1151/5000...
# Generating image 1161/5000...
# Generating image 1171/5000...
# Generating image 1181/5000...
# Generating image 1191/5000...
# Generating image 1201/5000...
# Generating image 1211/5000...
# Generating image 1221/5000...
# Generating image 1231/5000...
# Generating image 1241/5000...
# Generating image 1251/5000...
# Generating image 1261/5000...
# Generating image 1271/5000...
# Generating image 1281/5000...
# Generating image 1291/5000...
# Generating image 1301/5000...
# Generating image 1311/5000...
# Generating image 1321/5000...
# Generating image 1331/5000...
# Generating image 1341/5000...
# Generating image 1351/5000...
# Generating image 1361/5000...
# Generating image 1371/5000...
# Generating image 1381/5000...
# Generating image 1391/5000...
# Generating image 1401/5000...
# Generating image 1411/5000...
# Generating image 1421/5000...
# Generating image 1431/5000...
# Generating image 1441/5000...
# Generating image 1451/5000...
# Generating image 1461/5000...
# Generating image 1471/5000...
# Generating image 1481/5000...
# Generating image 1491/5000...
# Generating image 1501/5000...
# Generating image 1511/5000...
# Generating image 1521/5000...
# Generating image 1531/5000...
# Generating image 1541/5000...
# Generating image 1551/5000...
# Generating image 1561/5000...
# Generating image 1571/5000...
# Generating image 1581/5000...
# Generating image 1591/5000...
# Generating image 1601/5000...
# Generating image 1611/5000...
# Generating image 1621/5000...
# Generating image 1631/5000...
# Generating image 1641/5000...
# Generating image 1651/5000...
# Generating image 1661/5000...
# Generating image 1671/5000...
# Generating image 1681/5000...
# Generating image 1691/5000...
# Generating image 1701/5000...
# Generating image 1711/5000...
# Generating image 1721/5000...
# Generating image 1731/5000...
# Generating image 1741/5000...
# Generating image 1751/5000...
# Generating image 1761/5000...
# Generating image 1771/5000...
# Generating image 1781/5000...
# Generating image 1791/5000...
# Generating image 1801/5000...
# Generating image 1811/5000...
# Generating image 1821/5000...
# Generating image 1831/5000...
# Generating image 1841/5000...
# Generating image 1851/5000...
# Generating image 1861/5000...
# Generating image 1871/5000...
# Generating image 1881/5000...
# Generating image 1891/5000...
# Generating image 1901/5000...
# Generating image 1911/5000...
# Generating image 1921/5000...
# Generating image 1931/5000...
# Generating image 1941/5000...
# Generating image 1951/5000...
# Generating image 1961/5000...
# Generating image 1971/5000...
# Generating image 1981/5000...
# Generating image 1991/5000...
# Generating image 2001/5000...
# Generating image 2011/5000...
# Generating image 2021/5000...
# Generating image 2031/5000...
# Generating image 2041/5000...
# Generating image 2051/5000...
# Generating image 2061/5000...
# Generating image 2071/5000...
# Generating image 2081/5000...
# Generating image 2091/5000...
# Generating image 2101/5000...
# Generating image 2111/5000...
# Generating image 2121/5000...
# Generating image 2131/5000...
# Generating image 2141/5000...
# Generating image 2151/5000...
# Generating image 2161/5000...
# Generating image 2171/5000...
# Generating image 2181/5000...
# Generating image 2191/5000...
# Generating image 2201/5000...
# Generating image 2211/5000...
# Generating image 2221/5000...
# Generating image 2231/5000...
# Generating image 2241/5000...
# Generating image 2251/5000...
# Generating image 2261/5000...
# Generating image 2271/5000...
# Generating image 2281/5000...
# Generating image 2291/5000...
# Generating image 2301/5000...
# Generating image 2311/5000...
# Generating image 2321/5000...
# Generating image 2331/5000...
# Generating image 2341/5000...
# Generating image 2351/5000...
# Generating image 2361/5000...
# Generating image 2371/5000...
# Generating image 2381/5000...
# Generating image 2391/5000...
# Generating image 2401/5000...
# Generating image 2411/5000...
# Generating image 2421/5000...
# Generating image 2431/5000...
# Generating image 2441/5000...
# Generating image 2451/5000...
# Generating image 2461/5000...
# Generating image 2471/5000...
# Generating image 2481/5000...
# Generating image 2491/5000...
# Generating image 2501/5000...
# Generating image 2511/5000...
# Generating image 2521/5000...
# Generating image 2531/5000...
# Generating image 2541/5000...
# Generating image 2551/5000...
# Generating image 2561/5000...
# Generating image 2571/5000...
# Generating image 2581/5000...
# Generating image 2591/5000...
# Generating image 2601/5000...
# Generating image 2611/5000...
# Generating image 2621/5000...
# Generating image 2631/5000...
# Generating image 2641/5000...
# Generating image 2651/5000...
# Generating image 2661/5000...
# Generating image 2671/5000...
# Generating image 2681/5000...
# Generating image 2691/5000...
# Generating image 2701/5000...
# Generating image 2711/5000...
# Generating image 2721/5000...
# Generating image 2731/5000...
# Generating image 2741/5000...
# Generating image 2751/5000...
# Generating image 2761/5000...
# Generating image 2771/5000...
# Generating image 2781/5000...
# Generating image 2791/5000...
# Generating image 2801/5000...
# Generating image 2811/5000...
# Generating image 2821/5000...
# Generating image 2831/5000...
# Generating image 2841/5000...
# Generating image 2851/5000...
# Generating image 2861/5000...
# Generating image 2871/5000...
# Generating image 2881/5000...
# Generating image 2891/5000...
# Generating image 2901/5000...
# Generating image 2911/5000...
# Generating image 2921/5000...
# Generating image 2931/5000...
# Generating image 2941/5000...
# Generating image 2951/5000...
# Generating image 2961/5000...
# Generating image 2971/5000...
# Generating image 2981/5000...
# Generating image 2991/5000...
# Generating image 3001/5000...
# Generating image 3011/5000...
# Generating image 3021/5000...
# Generating image 3031/5000...
# Generating image 3041/5000...
# Generating image 3051/5000...
# Generating image 3061/5000...
# Generating image 3071/5000...
# Generating image 3081/5000...
# Generating image 3091/5000...
# Generating image 3101/5000...
# Generating image 3111/5000...
# Generating image 3121/5000...
# Generating image 3131/5000...
# Generating image 3141/5000...
# Generating image 3151/5000...
# Generating image 3161/5000...
# Generating image 3171/5000...
# Generating image 3181/5000...
# Generating image 3191/5000...
# Generating image 3201/5000...
# Generating image 3211/5000...
# Generating image 3221/5000...
# Generating image 3231/5000...
# Generating image 3241/5000...
# Generating image 3251/5000...
# Generating image 3261/5000...
# Generating image 3271/5000...
# Generating image 3281/5000...
# Generating image 3291/5000...
# Generating image 3301/5000...
# Generating image 3311/5000...
# Generating image 3321/5000...
# Generating image 3331/5000...
# Generating image 3341/5000...
# Generating image 3351/5000...
# Generating image 3361/5000...
# Generating image 3371/5000...
# Generating image 3381/5000...
# Generating image 3391/5000...
# Generating image 3401/5000...
# Generating image 3411/5000...
# Generating image 3421/5000...
# Generating image 3431/5000...
# Generating image 3441/5000...
# Generating image 3451/5000...
# Generating image 3461/5000...
# Generating image 3471/5000...
# Generating image 3481/5000...
# Generating image 3491/5000...
# Generating image 3501/5000...
# Generating image 3511/5000...
# Generating image 3521/5000...
# Generating image 3531/5000...
# Generating image 3541/5000...
# Generating image 3551/5000...
# Generating image 3561/5000...
# Generating image 3571/5000...
# Generating image 3581/5000...
# Generating image 3591/5000...
# Generating image 3601/5000...
# Generating image 3611/5000...
# Generating image 3621/5000...
# Generating image 3631/5000...
# Generating image 3641/5000...
# Generating image 3651/5000...
# Generating image 3661/5000...
# Generating image 3671/5000...
# Generating image 3681/5000...
# Generating image 3691/5000...
# Generating image 3701/5000...
# Generating image 3711/5000...
# Generating image 3721/5000...
# Generating image 3731/5000...
# Generating image 3741/5000...
# Generating image 3751/5000...
# Generating image 3761/5000...
# Generating image 3771/5000...
# Generating image 3781/5000...
# Generating image 3791/5000...
# Generating image 3801/5000...
# Generating image 3811/5000...
# Generating image 3821/5000...
# Generating image 3831/5000...
# Generating image 3841/5000...
# Generating image 3851/5000...
# Generating image 3861/5000...
# Generating image 3871/5000...
# Generating image 3881/5000...
# Generating image 3891/5000...
# Generating image 3901/5000...
# Generating image 3911/5000...
# Generating image 3921/5000...
# Generating image 3931/5000...
# Generating image 3941/5000...
# Generating image 3951/5000...
# Generating image 3961/5000...
# Generating image 3971/5000...
# Generating image 3981/5000...
# Generating image 3991/5000...
# Generating image 4001/5000...
# Generating image 4011/5000...
# Generating image 4021/5000...
# Generating image 4031/5000...
# Generating image 4041/5000...
# Generating image 4051/5000...
# Generating image 4061/5000...
# Generating image 4071/5000...
# Generating image 4081/5000...
# Generating image 4091/5000...
# Generating image 4101/5000...
# Generating image 4111/5000...
# Generating image 4121/5000...
# Generating image 4131/5000...
# Generating image 4141/5000...
# Generating image 4151/5000...
# Generating image 4161/5000...
# Generating image 4171/5000...
# Generating image 4181/5000...
# Generating image 4191/5000...
# Generating image 4201/5000...
# Generating image 4211/5000...
# Generating image 4221/5000...
# Generating image 4231/5000...
# Generating image 4241/5000...
# Generating image 4251/5000...
# Generating image 4261/5000...
# Generating image 4271/5000...
# Generating image 4281/5000...
# Generating image 4291/5000...
# Generating image 4301/5000...
# Generating image 4311/5000...
# Generating image 4321/5000...
# Generating image 4331/5000...
# Generating image 4341/5000...
# Generating image 4351/5000...
# Generating image 4361/5000...
# Generating image 4371/5000...
# Generating image 4381/5000...
# Generating image 4391/5000...
# Generating image 4401/5000...
# Generating image 4411/5000...
# Generating image 4421/5000...
# Generating image 4431/5000...
# Generating image 4441/5000...
# Generating image 4451/5000...
# Generating image 4461/5000...
# Generating image 4471/5000...
# Generating image 4481/5000...
# Generating image 4491/5000...
# Generating image 4501/5000...
# Generating image 4511/5000...
# Generating image 4521/5000...
# Generating image 4531/5000...
# Generating image 4541/5000...
# Generating image 4551/5000...
# Generating image 4561/5000...
# Generating image 4571/5000...
# Generating image 4581/5000...
# Generating image 4591/5000...
# Generating image 4601/5000...
# Generating image 4611/5000...
# Generating image 4621/5000...
# Generating image 4631/5000...
# Generating image 4641/5000...
# Generating image 4651/5000...
# Generating image 4661/5000...
# Generating image 4671/5000...
# Generating image 4681/5000...
# Generating image 4691/5000...
# Generating image 4701/5000...
# Generating image 4711/5000...
# Generating image 4721/5000...
# Generating image 4731/5000...
# Generating image 4741/5000...
# Generating image 4751/5000...
# Generating image 4761/5000...
# Generating image 4771/5000...
# Generating image 4781/5000...
# Generating image 4791/5000...
# Generating image 4801/5000...
# Generating image 4811/5000...
# Generating image 4821/5000...
# Generating image 4831/5000...
# Generating image 4841/5000...
# Generating image 4851/5000...
# Generating image 4861/5000...
# Generating image 4871/5000...
# Generating image 4881/5000...
# Generating image 4891/5000...
# Generating image 4901/5000...
# Generating image 4911/5000...
# Generating image 4921/5000...
# Generating image 4931/5000...
# Generating image 4941/5000...
# Generating image 4951/5000...
# Generating image 4961/5000...
# Generating image 4971/5000...
# Generating image 4981/5000...
# Generating image 4991/5000...
# Generated 5000 synthetic images and annotations in C:\Users\mohan\Desktop\blister\ml_app\datasets\synthetic_dataset
# Distribution: 3500 train, 1000 test, 500 val
# Total time taken: 2701.53 seconds
# Script execution completed.
